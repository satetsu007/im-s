# %%
# coding:utf-8

import os
import sys
import cv2
import shutil
import matplotlib.pyplot as plt
from anime_module import get_list,make_folder

make_folder()

photo_list = get_list("tmp/")

for i in range(len(photo_list)):
    if i%5 == 0:
        img = cv2.imread("tmp/" + photo_list[i])
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        print(photo_list[i])
        print("このアイドルの名前は？")
        plt.show()
        idol_name = input()

        if idol_name == "天海春香":
            shutil.move("tmp/" + photo_list[i], "天海春香/" + photo_list[i])
            print(idol_name + "に移動しました")

        elif idol_name == "菊地真":
            shutil.move("tmp/" + photo_list[i], "菊地真/" + photo_list[i])
            print(idol_name + "に移動しました")

        elif idol_name == "荻原雪歩":
            shutil.move("tmp/" + photo_list[i], "荻原雪歩/" + photo_list[i])
            print(idol_name + "に移動しました")

        elif idol_name == "双海真美":
            shutil.move("tmp/" + photo_list[i], "双海真美/" + photo_list[i])
            print(idol_name + "に移動しました")

        elif idol_name == "双海亜美":
            shutil.move("tmp/" + photo_list[i], "双海亜美/" + photo_list[i])
            print(idol_name + "に移動しました")

        elif idol_name == "四条貴音":
            shutil.move("tmp/" + photo_list[i], "四条貴音/" + photo_list[i])

        elif idol_name == "我那覇響":
            shutil.move("tmp/" + photo_list[i], "我那覇響/" + photo_list[i])
            print(idol_name + "に移動しました")

        elif idol_name == "如月千早":
            shutil.move("tmp/" + photo_list[i], "如月千早/" + photo_list[i])
            print(idol_name + "に移動しました")

        elif idol_name == "星井美希":
            shutil.move("tmp/" + photo_list[i], "星井美希/" + photo_list[i])
            print(idol_name + "に移動しました")

        elif idol_name == "水瀬伊織":
            shutil.move("tmp/" + photo_list[i], "水瀬伊織/" + photo_list[i])
            print(idol_name + "に移動しました")

        elif idol_name == "三浦あずさ":
            shutil.move("tmp/" + photo_list[i], "三浦あずさ/" + photo_list[i])
            print(idol_name + "に移動しました")

        elif idol_name == "秋月律子":
            shutil.move("tmp/" + photo_list[i], "秋月律子/" + photo_list[i])
            print(idol_name + "に移動しました")

        elif idol_name == "秋月涼":
            shutil.move("tmp/" + photo_list[i], "秋月涼/" + photo_list[i])
            print(idol_name + "に移動しました")

        elif idol_name == "音無小鳥":
            shutil.move("tmp/" + photo_list[i], "音無小鳥/" + photo_list[i])
            print(idol_name + "に移動しました")

        elif idol_name == "高槻やよい":
            shutil.move("tmp/" + photo_list[i], "音無小鳥/" + photo_list[i])
            print(idol_name + "に移動しました")

        elif idol_name == "赤羽P":
            shutil.move("tmp/" + photo_list[i], "赤羽P/" + photo_list[i])
            print(idol_name + "に移動しました")

        elif idol_name == "社長":
            shutil.move("tmp/" + photo_list[i], "社長/" + photo_list[i])
            print(idol_name + "に移動しました")

        elif idol_name == "モブキャラ":
            shutil.move("tmp/" + photo_list[i], "モブキャラ/" + photo_list[i])
            print(idol_name + "に移動しました")

        elif idol_name == "誤分類":
            shutil.move("tmp/" + photo_list[i], "誤分類/" + photo_list[i])
            print(idol_name + "に移動しました")

        else:
            shutil.move("tmp/" + photo_list[i], "誤分類/" + photo_list[i])
            print("誤分類" + "に移動しました")

    else:
        if idol_name == "天海春香":
            shutil.move("tmp/" + photo_list[i], "天海春香/" + photo_list[i])

        elif idol_name == "菊地真":
            shutil.move("tmp/" + photo_list[i], "菊地真/" + photo_list[i])

        elif idol_name == "荻原雪歩":
            shutil.move("tmp/" + photo_list[i], "荻原雪歩/" + photo_list[i])

        elif idol_name == "双海真美":
            shutil.move("tmp/" + photo_list[i], "双海真美/" + photo_list[i])

        elif idol_name == "双海亜美":
            shutil.move("tmp/" + photo_list[i], "双海亜美/" + photo_list[i])

        elif idol_name == "四条貴音":
            shutil.move("tmp/" + photo_list[i], "四条貴音/" + photo_list[i])

        elif idol_name == "我那覇響":
            shutil.move("tmp/" + photo_list[i], "我那覇響/" + photo_list[i])

        elif idol_name == "如月千早":
            shutil.move("tmp/" + photo_list[i], "如月千早/" + photo_list[i])

        elif idol_name == "星井美希":
            shutil.move("tmp/" + photo_list[i], "星井美希/" + photo_list[i])

        elif idol_name == "水瀬伊織":
            shutil.move("tmp/" + photo_list[i], "水瀬伊織/" + photo_list[i])

        elif idol_name == "高槻やよい":
            shutil.move("tmp/" + photo_list[i], "音無小鳥/" + photo_list[i])

        elif idol_name == "三浦あずさ":
            shutil.move("tmp/" + photo_list[i], "三浦あずさ/" + photo_list[i])

        elif idol_name == "秋月律子":
            shutil.move("tmp/" + photo_list[i], "秋月律子/" + photo_list[i])

        elif idol_name == "秋月涼":
            shutil.move("tmp/" + photo_list[i], "秋月律子/" + photo_list[i])

        elif idol_name == "音無小鳥":
            shutil.move("tmp/" + photo_list[i], "音無小鳥/" + photo_list[i])

        elif idol_name == "赤羽P":
            shutil.move("tmp/" + photo_list[i], "赤羽P/" + photo_list[i])

        elif idol_name == "社長":
            shutil.move("tmp/" + photo_list[i], "社長/" + photo_list[i])

        elif idol_name == "モブキャラ":
            shutil.move("tmp/" + photo_list[i], "モブキャラ/" + photo_list[i])

        elif idol_name == "誤分類":
            shutil.move("tmp/" + photo_list[i], "誤分類/" + photo_list[i])

        else:
            shutil.move("tmp/" + photo_list[i], "誤分類/" + photo_list[i])
# Out:
# フォルダを作成しました
# 142.jpg
# このアイドルの名前は？
# 如月千早
# 如月千早に移動しました
# 143.jpg
# このアイドルの名前は？
# モブキャラ
# モブキャラに移動しました
# 144.jpg
# このアイドルの名前は？
# モブキャラ
# モブキャラに移動しました
# 145.jpg
# このアイドルの名前は？
# 天海春香
# 天海春香に移動しました
# 146.jpg
# このアイドルの名前は？
# モブキャラ
# モブキャラに移動しました
# 147.jpg
# このアイドルの名前は？
# 天海春香
# 天海春香に移動しました
# 148.jpg
# このアイドルの名前は？
# 天海春香
# 天海春香に移動しました
# 149.jpg
# このアイドルの名前は？
# 三浦あずさ
# 三浦あずさに移動しました
# 15.jpg
# このアイドルの名前は？
# 秋月律子
# 秋月律子に移動しました
# 150.jpg
# このアイドルの名前は？
# 高槻やよい
# 高槻やよいに移動しました
# 151.jpg
# このアイドルの名前は？
